# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\inaya\anaconda3\lib\site-packages (37.1.0)
# Requirement already satisfied: tzdata in c:\users\inaya\anaconda3\lib\site-packages (from faker) (2023.3)

# %%
from faker import Faker

# %%
fake = Faker("id_ID")

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in c:\users\inaya\anaconda3\lib\site-packages (0.9.0)

# %%
# menampilkan tabel 
from tabulate import tabulate

def show_data(table):
    tab = tabulate(tabular_data=table,
                   headers=table.keys(),
                   tablefmt="psql",
                   numalign="center")
    print(tab)

# %%
# membuat dummy data table library 
def library(n_cust, is_print):
    tabel = {}
    tabel["library_id"] = [i+1 for i in range(n_cust)]
    tabel["library_name"] = [fake.company() for i in range(n_cust)]
    tabel["address"] = [fake.address() for i in range(n_cust)]
    if is_print:
        show_data(tabel)
        
    return tabel

# %%
library = library(100, True)
# Out:
# +--------------+------------------------------------------+---------------------------------------------------------+
# |  library_id  | library_name                             | address                                                 |
# |--------------+------------------------------------------+---------------------------------------------------------|
# |      1       | CV Hassanah Tbk                          | Jl. H.J Maemunah No. 3                                  |
# |              |                                          | Banjarbaru, Sulawesi Utara 69564                        |
# |      2       | PT Andriani Lailasari                    | Gang Laswi No. 778                                      |
# |              |                                          | Pekanbaru, JA 67585                                     |
# |      3       | PD Saputra (Persero) Tbk                 | Jl. Asia Afrika No. 008                                 |
# |              |                                          | Bontang, SG 49274                                       |
# |      4       | PD Rajasa                                | Jalan Ciumbuleuit No. 63                                |
# |              |                                          | Pontianak, PA 30002                                     |
# |      5       | PD Santoso (Persero) Tbk                 | Jl. Kutai No. 0                                         |
# |              |                                          | Sawahlunto, Kalimantan Utara 12647                      |
# |      6       | CV Andriani Gunarto Tbk                  | Gang Sadang Serang No. 46                               |
# |              |                                          | Sawahlunto, SG 89894                                    |
# |      7       | PT Safitri Kuswoyo Tbk                   | Jalan Rajawali Barat No. 525                            |
# |              |                                          | Gorontalo, NB 95247                                     |
# |      8       | PT Ardianto (Persero) Tbk                | Jalan Rungkut Industri No. 706                          |
# |              |                                          | Kota Administrasi Jakarta Barat, SB 54422               |
# |      9       | PD Rajata                                | Jl. Dipenogoro No. 6                                    |
# |              |                                          | Kota Administrasi Jakarta Barat, KS 23307               |
# |      10      | PD Nainggolan                            | Jl. Rungkut Industri No. 50                             |
# |              |                                          | Kotamobagu, DI Yogyakarta 67288                         |
# |      11      | UD Ardianto Tbk                          | Jl. Medokan Ayu No. 648                                 |
# |              |                                          | Metro, JI 63666                                         |
# |      12      | PD Samosir Tbk                           | Jl. S. Parman No. 518                                   |
# |              |                                          | Pagaralam, GO 89401                                     |
# |      13      | PT Wastuti Budiman (Persero) Tbk         | Gang Abdul Muis No. 475                                 |
# |              |                                          | Gorontalo, Gorontalo 12061                              |
# |      14      | Perum Nashiruddin (Persero) Tbk          | Gg. Veteran No. 4                                       |
# |              |                                          | Binjai, AC 39671                                        |
# |      15      | UD Farida (Persero) Tbk                  | Jalan Gedebage Selatan No. 16                           |
# |              |                                          | Tanjungpinang, SB 78735                                 |
# |      16      | Perum Sirait Prayoga Tbk                 | Gang Rumah Sakit No. 2                                  |
# |              |                                          | Tanjungpinang, KI 85412                                 |
# |      17      | CV Tamba                                 | Gg. Rawamangun No. 33                                   |
# |              |                                          | Padangpanjang, KU 08914                                 |
# |      18      | PT Mahendra Tbk                          | Jl. Rungkut Industri No. 889                            |
# |              |                                          | Kediri, KR 35149                                        |
# |      19      | CV Lailasari                             | Jl. Cihampelas No. 5                                    |
# |              |                                          | Banjarmasin, Nusa Tenggara Barat 05221                  |
# |      20      | PD Tarihoran Pradana                     | Gg. M.T Haryono No. 620                                 |
# |              |                                          | Pematangsiantar, AC 59940                               |
# |      21      | Perum Anggriawan Tbk                     | Jl. W.R. Supratman No. 659                              |
# |              |                                          | Kota Administrasi Jakarta Timur, Kalimantan Barat 36575 |
# |      22      | PT Hakim                                 | Gang Dipatiukur No. 992                                 |
# |              |                                          | Kotamobagu, BT 51760                                    |
# |      23      | UD Maulana Tbk                           | Gang Erlangga No. 7                                     |
# |              |                                          | Sukabumi, Papua Barat 99072                             |
# |      24      | PT Astuti Nasyidah                       | Jl. Antapani Lama No. 73                                |
# |              |                                          | Manado, SB 38665                                        |
# |      25      | PT Firgantoro Tbk                        | Gg. Merdeka No. 92                                      |
# |              |                                          | Banjarmasin, ST 84157                                   |
# |      26      | Perum Purnawati Hutasoit                 | Jl. Kapten Muslihat No. 942                             |
# |              |                                          | Depok, Jawa Barat 26552                                 |
# |      27      | PT Wijayanti                             | Gang Wonoayu No. 88                                     |
# |              |                                          | Kupang, Sulawesi Selatan 56594                          |
# |      28      | UD Nababan Maulana Tbk                   | Jl. Sentot Alibasa No. 691                              |
# |              |                                          | Bontang, Nusa Tenggara Barat 05302                      |
# |      29      | PD Winarsih Hariyah                      | Jl. Merdeka No. 126                                     |
# |              |                                          | Serang, JA 59314                                        |
# |      30      | PT Dabukke                               | Jl. Sentot Alibasa No. 111                              |
# |              |                                          | Purwokerto, Kepulauan Bangka Belitung 52379             |
# |      31      | PD Wahyuni Wijaya                        | Gang Sukajadi No. 8                                     |
# |              |                                          | Padangpanjang, Sulawesi Tengah 49181                    |
# |      32      | Perum Hutagalung Kurniawan               | Jl. Erlangga No. 90                                     |
# |              |                                          | Malang, SR 39059                                        |
# |      33      | PD Mulyani (Persero) Tbk                 | Jalan Peta No. 800                                      |
# |              |                                          | Tanjungbalai, JB 21454                                  |
# |      34      | PD Permata                               | Jalan Monginsidi No. 255                                |
# |              |                                          | Tanjungpinang, BE 75057                                 |
# |      35      | Perum Situmorang                         | Jalan Setiabudhi No. 9                                  |
# |              |                                          | Cilegon, Sulawesi Barat 46093                           |
# |      36      | UD Aryani Tamba Tbk                      | Jalan Gardujati No. 1                                   |
# |              |                                          | Kota Administrasi Jakarta Selatan, Sulawesi Barat 34728 |
# |      37      | CV Hutasoit Padmasari Tbk                | Gang Kutisari Selatan No. 5                             |
# |              |                                          | Cirebon, Sumatera Utara 90339                           |
# |      38      | CV Prasasta Kusumo                       | Jl. M.H Thamrin No. 7                                   |
# |              |                                          | Pekalongan, MA 81543                                    |
# |      39      | CV Laksmiwati Permadi (Persero) Tbk      | Gang Dipatiukur No. 31                                  |
# |              |                                          | Balikpapan, BE 01763                                    |
# |      40      | PD Hakim Novitasari Tbk                  | Jalan Kebonjati No. 78                                  |
# |              |                                          | Ambon, Maluku 42274                                     |
# |      41      | PT Dongoran (Persero) Tbk                | Gang Rajiman No. 55                                     |
# |              |                                          | Binjai, Kalimantan Selatan 85002                        |
# |      42      | PD Anggraini Mandala                     | Gang Veteran No. 68                                     |
# |              |                                          | Magelang, KT 60457                                      |
# |      43      | PD Tamba Lestari (Persero) Tbk           | Gang Ahmad Yani No. 1                                   |
# |              |                                          | Probolinggo, KR 76447                                   |
# |      44      | Perum Widiastuti Narpati                 | Jl. Otto Iskandardinata No. 71                          |
# |              |                                          | Tasikmalaya, SS 52126                                   |
# |      45      | UD Rahayu                                | Gg. Kebonjati No. 29                                    |
# |              |                                          | Sabang, Sulawesi Barat 28287                            |
# |      46      | UD Novitasari Tbk                        | Jl. Joyoboyo No. 45                                     |
# |              |                                          | Bogor, YO 95855                                         |
# |      47      | CV Hartati                               | Jl. Wonoayu No. 21                                      |
# |              |                                          | Pariaman, Banten 67950                                  |
# |      48      | Perum Rahayu Widiastuti Tbk              | Gang Jend. Sudirman No. 51                              |
# |              |                                          | Bogor, Nusa Tenggara Timur 93941                        |
# |      49      | CV Dongoran Winarsih Tbk                 | Jl. Cempaka No. 969                                     |
# |              |                                          | Serang, Aceh 69623                                      |
# |      50      | UD Hutagalung Oktaviani                  | Gang Surapati No. 6                                     |
# |              |                                          | Kendari, MU 89829                                       |
# |      51      | PT Rahimah Lailasari (Persero) Tbk       | Gang Pelajar Pejuang No. 3                              |
# |              |                                          | Pematangsiantar, SB 31204                               |
# |      52      | UD Nuraini Palastri Tbk                  | Jl. Jend. Sudirman No. 476                              |
# |              |                                          | Sibolga, RI 57522                                       |
# |      53      | PD Saptono Andriani                      | Gang Kapten Muslihat No. 8                              |
# |              |                                          | Banjar, RI 15117                                        |
# |      54      | PT Widodo Mansur                         | Gg. Kutai No. 467                                       |
# |              |                                          | Salatiga, SR 64838                                      |
# |      55      | PD Padmasari Tbk                         | Jl. Sukajadi No. 99                                     |
# |              |                                          | Tegal, SB 01158                                         |
# |      56      | PT Natsir Wijaya                         | Jalan Ronggowarsito No. 987                             |
# |              |                                          | Banjar, Kalimantan Timur 61642                          |
# |      57      | PT Putra                                 | Gg. Antapani Lama No. 543                               |
# |              |                                          | Banda Aceh, Sulawesi Utara 09496                        |
# |      58      | Perum Pradana                            | Gg. Ir. H. Djuanda No. 317                              |
# |              |                                          | Metro, Jambi 92802                                      |
# |      59      | UD Anggriawan Marbun Tbk                 | Jalan Ronggowarsito No. 56                              |
# |              |                                          | Sukabumi, ST 54818                                      |
# |      82      | PD Sihotang Haryanto Tbk                 | Jl. S. Parman No. 65                                    |
# |              |                                          | Bitung, Nusa Tenggara Barat 50843                       |
# |      83      | PT Lestari Sihombing Tbk                 | Gang Kutai No. 43                                       |
# |              |                                          | Manado, KI 90101                                        |
# |      84      | UD Ardianto Hassanah                     | Jalan S. Parman No. 554                                 |
# |              |                                          | Banjarmasin, Kepulauan Riau 27838                       |
# |      85      | CV Ardianto Laksita Tbk                  | Jalan Suryakencana No. 0                                |
# |              |                                          | Padang, JK 69151                                        |
# |      86      | CV Kusmawati Utama Tbk                   | Gang W.R. Supratman No. 9                               |
# |              |                                          | Sungai Penuh, JK 43257                                  |
# |      87      | PT Gunarto Budiman Tbk                   | Gg. Waringin No. 82                                     |
# |              |                                          | Banjarbaru, Papua 54463                                 |
# |      88      | Perum Pratama Hassanah                   | Gang Erlangga No. 78                                    |
# |              |                                          | Malang, MU 40192                                        |
# |      89      | PD Siregar Sinaga                        | Gg. Suniaraja No. 389                                   |
# |              |                                          | Makassar, Sulawesi Barat 95690                          |
# |      90      | PT Damanik Kusmawati                     | Gang M.H Thamrin No. 9                                  |
# |              |                                          | Kotamobagu, Sulawesi Utara 22813                        |
# |      91      | Perum Dongoran                           | Jl. Rajiman No. 44                                      |
# |              |                                          | Parepare, Sumatera Barat 27546                          |
# |      92      | UD Wibisono Salahudin (Persero) Tbk      | Gang Dipatiukur No. 142                                 |
# |              |                                          | Sukabumi, BT 79798                                      |
# |      93      | PD Firgantoro Irawan                     | Gang Merdeka No. 25                                     |
# |              |                                          | Tangerang Selatan, Kalimantan Barat 16585               |
# |      94      | UD Maheswara Tbk                         | Gang Jend. Sudirman No. 16                              |
# |              |                                          | Bogor, KB 36507                                         |
# |      95      | Perum Haryanto Wahyuni                   | Jl. Rumah Sakit No. 8                                   |
# |              |                                          | Kota Administrasi Jakarta Utara, Gorontalo 82182        |
# |      96      | Perum Saefullah Hutagalung Tbk           | Jalan Cikutra Timur No. 845                             |
# |              |                                          | Sungai Penuh, Kalimantan Tengah 42734                   |
# |      97      | Perum Megantara                          | Gg. Jayawijaya No. 63                                   |
# |              |                                          | Palu, Jawa Tengah 57049                                 |
# |      98      | Perum Adriansyah                         | Jl. Cihampelas No. 2                                    |
# |              |                                          | Sungai Penuh, BA 92760                                  |
# |      99      | UD Puspita Padmasari Tbk                 | Jalan Laswi No. 7                                       |
# |              |                                          | Denpasar, GO 17395                                      |
# |     100      | PD Siregar Tbk                           | Gg. Surapati No. 409                                    |
# |              |                                          | Sorong, Jawa Tengah 42995                               |
# +--------------+------------------------------------------+---------------------------------------------------------+

# %%
# meyimpan file kedalam csv 
import csv

# %%
def save_to_csv(data, nama_file):
    '''
    Fungsi untuk menyimpan data dummy ke csv

    args:
        - data (list)     : list of dictionary data yang akan dijadikan csv
        - nama_file (str) : nama untuk file csv

	return:
		- None
    '''

    # Membuat file csv
    with open(file = f"{nama_file}.csv", mode = 'w', newline = '') as csv_file:
        # Membuat writer csv
        writer = csv.writer(csv_file)

        # write header csv
        writer.writerow(list(data.keys()))

        # mengetahui panjang data
        len_data = len(list(data.items())[0][1])

        # write data ke file csv
        for i in range(len_data):
            row = []
            for key in data.keys():
                row.append(data[key][i])
            writer.writerow(row)

# %%
save_to_csv(data = library,
            nama_file = 'library')

# %%
# membuat tabel category 
kategori_buku = [
    "Fiksi", "Non-Fiksi", "Biografi", "Fantasi", "Sains", "Teknologi",
    "Sejarah", "Romantis", "Misteri", "Thriller", "Horror", "Psikologi",
    "Agama", "Pendidikan", "Bisnis", "Anak-anak", "Sastra", "Self-Improvement"
]

def category(is_print):
    n_cust = len(kategori_buku)
    tabel = {}
    tabel["category_id"] = [i+1 for i in range(n_cust)]
    tabel["category"] = kategori_buku.copy()
    if is_print:
        show_data(tabel)
        
    return tabel

# %%
category = category(True)
# Out:
# +---------------+------------------+
# |  category_id  | category         |
# |---------------+------------------|
# |       1       | Fiksi            |
# |       2       | Non-Fiksi        |
# |       3       | Biografi         |
# |       4       | Fantasi          |
# |       5       | Sains            |
# |       6       | Teknologi        |
# |       7       | Sejarah          |
# |       8       | Romantis         |
# |       9       | Misteri          |
# |      10       | Thriller         |
# |      11       | Horror           |
# |      12       | Psikologi        |
# |      13       | Agama            |
# |      14       | Pendidikan       |
# |      15       | Bisnis           |
# |      16       | Anak-anak        |
# |      17       | Sastra           |
# |      18       | Self-Improvement |
# +---------------+------------------+

# %%
import csv

# %%
save_to_csv(data = category,
            nama_file = 'category')

# %%
import random

# %%
#memampilkan judul buku 
def fake_judul():
    return ' '.join(fake.words(nb=random.randint(2, 5))).title()

# membuat tabel book 
def book(n_cust, is_print):
    tabel = {}
    tabel["book_id"] = [f" B - {i+1:03}" for i in range(n_cust)]
    tabel["category_id"] = [random.choice (category["category_id"])  for i in range(n_cust)]
    tabel["judul"] = [fake_judul() for i in range(n_cust)]
    tabel["penulis"] = [fake.name() for i in range(n_cust)]
    if is_print:
        show_data(tabel)
        
    return tabel

# %%
book = book(100, True)
# Out:
# +-----------+---------------+--------------------------------------------------------+-----------------------------+
# | book_id   |  category_id  | judul                                                  | penulis                     |
# |-----------+---------------+--------------------------------------------------------+-----------------------------|
# | B - 001   |      17       | Assumenda Nobis At Recusandae Vero                     | Panji Saputra               |
# | B - 002   |       7       | Esse Sed Vel Asperiores                                | Cager Kuswoyo               |
# | B - 003   |      18       | Voluptate Error                                        | Patricia Purnawati, S.T.    |
# | B - 004   |      13       | Iure Sunt Accusantium Consequatur                      | Lurhur Zulkarnain, M.Farm   |
# | B - 005   |       6       | Ab Maiores                                             | R. Soleh Anggraini, S.Farm  |
# | B - 006   |       4       | Aut Doloremque Quo Culpa Nihil                         | R. Hesti Firgantoro         |
# | B - 007   |       6       | Adipisci Reprehenderit Atque                           | Irma Halimah                |
# | B - 008   |      17       | Voluptate Ut A Fuga                                    | Ami Palastri                |
# | B - 009   |      18       | Officia Id                                             | Padma Rajasa                |
# | B - 081   |      17       | Inventore Laudantium                                   | Danuja Iswahyudi            |
# | B - 082   |      12       | Voluptate Non                                          | Ghaliyati Mandasari         |
# | B - 083   |       6       | Aut Officia Natus                                      | Tami Siregar, S.Pt          |
# | B - 084   |      10       | Delectus Facere Asperiores                             | Mala Ardianto               |
# | B - 085   |       7       | Rem Doloremque Nihil Dignissimos Similique             | Jane Prakasa                |
# | B - 086   |      18       | Earum Ut Consectetur Fugit                             | Balapati Palastri           |
# | B - 087   |      13       | Temporibus A Distinctio Earum                          | Ir. Damar Widodo, S.Sos     |
# | B - 088   |       1       | Quam Magnam Est                                        | Kasiyah Maryati             |
# | B - 089   |      13       | Incidunt Maiores Repellat Fugiat                       | Iriana Sihombing            |
# | B - 090   |       9       | Autem Dolorem Corporis Asperiores                      | Maryanto Santoso            |
# | B - 091   |      16       | Et Veritatis Ut Ipsa Quibusdam                         | Dt. Muni Wacana             |
# | B - 092   |       7       | Vitae Deleniti                                         | Timbul Wibisono             |
# | B - 093   |       2       | Asperiores Inventore Dolorum Nostrum Nisi              | Dacin Suryatmi              |
# | B - 094   |      16       | Blanditiis Minus                                       | Paris Astuti                |
# | B - 095   |      12       | Reiciendis Ab Laboriosam                               | R. Gaman Januar             |
# | B - 096   |      10       | Corporis Doloremque Velit Illum                        | Azalea Budiman              |
# | B - 097   |      10       | Deserunt Nam Eius Provident Praesentium                | Cemani Hartati              |
# | B - 098   |      12       | Eaque Voluptate                                        | Gandewa Mahendra, S.Pt      |
# | B - 099   |      18       | Possimus Molestias                                     | Irma Purnawati, M.Pd        |
# | B - 100   |       7       | Accusantium Ducimus                                    | Hj. Keisha Hutapea, M.Ak    |
# +-----------+---------------+--------------------------------------------------------+-----------------------------+

# %%
save_to_csv(data = book,
            nama_file = 'book')

# %%
# membuat table book_library 
def book_library(n_cust, is_print):
    tabel = {}
    tabel["book_library_id"] = [ i+1 for i in range(n_cust)]
    tabel["library_id"] = [random.choice(library["library_id"]) for i in range(n_cust)]
    tabel["book_id"] = [random.choice(book["book_id"]) for i in range(n_cust)]
    tabel["quantity"] = [fake.random_int(min = 1) for i in range(n_cust)]
    if is_print:
        show_data(tabel)
    return tabel

# %%
book_library = book_library(100, True)
# Out:
# +-------------------+--------------+-----------+------------+
# |  book_library_id  |  library_id  | book_id   |  quantity  |
# |-------------------+--------------+-----------+------------|
# |         1         |      77      | B - 004   |    1696    |
# |         2         |      1       | B - 059   |    2899    |
# |         3         |      67      | B - 040   |    2137    |
# |         4         |      84      | B - 085   |    1509    |
# |         5         |      34      | B - 011   |    1760    |
# |         6         |      49      | B - 095   |    174     |
# |         7         |      27      | B - 033   |    2262    |
# |         8         |      38      | B - 037   |    7185    |
# |         9         |      99      | B - 091   |    9072    |
# |        10         |      34      | B - 036   |    6380    |
# |        11         |      36      | B - 007   |    391     |
# |        12         |      25      | B - 058   |    699     |
# |        13         |      94      | B - 082   |    7935    |
# |        14         |      2       | B - 092   |    6228    |
# |        15         |      13      | B - 095   |    1912    |
# |        16         |      6       | B - 024   |    8268    |
# |        17         |      3       | B - 012   |    5251    |
# |        18         |      63      | B - 008   |    7283    |
# |        19         |      88      | B - 030   |    5818    |
# |        20         |      63      | B - 066   |    9945    |
# |        21         |      5       | B - 055   |    4344    |
# |        22         |      88      | B - 047   |    5566    |
# |        23         |      86      | B - 004   |    5478    |
# |        24         |      9       | B - 061   |    4999    |
# |        25         |      85      | B - 053   |    8440    |
# |        26         |      94      | B - 068   |     95     |
# |        27         |      83      | B - 058   |    4799    |
# |        28         |      84      | B - 002   |    9534    |
# |        29         |      62      | B - 091   |    3355    |
# |        30         |      47      | B - 017   |    3040    |
# |        31         |      34      | B - 097   |    8946    |
# |        32         |      46      | B - 078   |    4248    |
# |        33         |      22      | B - 083   |    3345    |
# |        34         |      51      | B - 001   |    2569    |
# |        35         |      25      | B - 051   |    2641    |
# |        36         |      24      | B - 088   |    444     |
# |        37         |      44      | B - 030   |    7515    |
# |        38         |      93      | B - 068   |    1062    |
# |        39         |      89      | B - 057   |    9448    |
# |        40         |      1       | B - 052   |    736     |
# |        41         |      66      | B - 023   |    5049    |
# |        42         |      55      | B - 005   |    2483    |
# |        43         |      54      | B - 069   |    2238    |
# |        44         |      63      | B - 085   |    3843    |
# |        45         |      3       | B - 035   |    1041    |
# |        46         |      68      | B - 076   |    6875    |
# |        47         |      85      | B - 055   |    1640    |
# |        48         |      89      | B - 007   |    3659    |
# |        49         |      82      | B - 063   |    5811    |
# |        50         |      36      | B - 061   |    8429    |
# |        51         |      21      | B - 040   |    4174    |
# |        52         |      30      | B - 069   |    7266    |
# |        53         |      89      | B - 075   |    6842    |
# |        54         |      88      | B - 078   |    2647    |
# |        55         |      73      | B - 099   |    197     |
# |        56         |      16      | B - 035   |    3745    |
# |        57         |      55      | B - 097   |    8418    |
# |        58         |      86      | B - 046   |    4733    |
# |        59         |      12      | B - 082   |    6609    |
# |        60         |      74      | B - 067   |    8885    |
# |        61         |      31      | B - 015   |    9981    |
# |        62         |      85      | B - 042   |    6286    |
# |        63         |      41      | B - 081   |    1933    |
# |        64         |      45      | B - 038   |    874     |
# |        65         |      89      | B - 029   |    4351    |
# |        66         |      79      | B - 071   |    4503    |
# |        67         |      37      | B - 076   |    8767    |
# |        68         |      63      | B - 083   |    647     |
# |        69         |      69      | B - 033   |    1806    |
# |        70         |      50      | B - 069   |    5176    |
# |        71         |      7       | B - 050   |    8212    |
# |        72         |      18      | B - 067   |    4548    |
# |        73         |      6       | B - 085   |    2734    |
# |        74         |      60      | B - 050   |    7086    |
# |        75         |      14      | B - 062   |    4598    |
# |        76         |      42      | B - 092   |    4214    |
# |        77         |      24      | B - 036   |    6710    |
# |        78         |      61      | B - 065   |    8149    |
# |        79         |      70      | B - 030   |    9731    |
# |        80         |      86      | B - 045   |    6014    |
# |        81         |      61      | B - 072   |    5529    |
# |        82         |      39      | B - 063   |    650     |
# |        83         |      7       | B - 017   |    7461    |
# |        84         |      63      | B - 019   |    9027    |
# |        85         |      52      | B - 045   |    2134    |
# |        86         |      31      | B - 055   |    3195    |
# |        87         |      7       | B - 099   |    5731    |
# |        88         |      81      | B - 070   |    3962    |
# |        89         |      50      | B - 040   |    6168    |
# |        90         |      21      | B - 070   |    906     |
# |        91         |      54      | B - 009   |    478     |
# |        92         |      33      | B - 031   |    3828    |
# |        93         |      96      | B - 063   |    1906    |
# |        94         |      33      | B - 083   |    1466    |
# |        95         |      65      | B - 048   |    521     |
# |        96         |      30      | B - 091   |    6085    |
# |        97         |      21      | B - 099   |    1421    |
# |        98         |      14      | B - 056   |    3964    |
# |        99         |      60      | B - 054   |    4640    |
# |        100        |      16      | B - 007   |    7323    |
# +-------------------+--------------+-----------+------------+

# %%
save_to_csv(data = book_library,
            nama_file = 'book_library')

# %%
# membuat tabel users 
def users(n_cust, is_print):
    tabel = {
        "users_id" : [ i+1 for i in range(n_cust)],
        "name" : [],
        "email" : [],
        "password" :[f"{fake.words(nb=1)[0]}{fake.random_int(max=99)}" for i in range(n_cust)] }
    for _ in range(n_cust):
        nama = fake.name()
        nama_1 = "".join(nama.split()[:2])
        nama_bersih = nama_1.lower().replace(" ", "").replace(".", "")
        email = f"{nama_bersih}@gmail.com"
    

        tabel["name"].append(nama)
        tabel["email"].append(email)
    
    if is_print:
        show_data(tabel)
    return tabel

# %%
users = users(100, True)
# Out:
# +------------+---------------------------------+-----------------------------+-----------------+
# |  users_id  | name                            | email                       | password        |
# |------------+---------------------------------+-----------------------------+-----------------|
# |     1      | Clara Pratiwi                   | clarapratiwi@gmail.com      | porro73         |
# |     2      | T. Edi Putra, M.Ak              | tedi@gmail.com              | nemo28          |
# |     3      | Mulyono Mandala                 | mulyonomandala@gmail.com    | suscipit25      |
# |     4      | Gabriella Yulianti              | gabriellayulianti@gmail.com | nihil15         |
# |     5      | Janet Andriani                  | janetandriani@gmail.com     | ad21            |
# |     6      | Puji Suwarno                    | pujisuwarno@gmail.com       | neque77         |
# |     7      | Puti Natalia Nababan            | putinatalia@gmail.com       | ad11            |
# |     8      | Zahra Putra                     | zahraputra@gmail.com        | corporis64      |
# |     9      | Restu Utami                     | restuutami@gmail.com        | id73            |
# |     10     | R.M. Ibrahim Marbun, S.Gz       | rmibrahim@gmail.com         | libero26        |
# |     11     | drg. Jaiman Hidayat, S.Farm     | drgjaiman@gmail.com         | ullam23         |
# |     12     | Vero Kuswoyo, M.Farm            | verokuswoyo,@gmail.com      | aut46           |
# |     13     | Maman Mahendra                  | mamanmahendra@gmail.com     | iure53          |
# |     14     | Puti Usyi Puspita               | putiusyi@gmail.com          | aliquam50       |
# |     15     | Fitria Oktaviani                | fitriaoktaviani@gmail.com   | nam89           |
# |     16     | Gilang Setiawan, S.Psi          | gilangsetiawan,@gmail.com   | fugiat42        |
# |     17     | Ika Pradipta                    | ikapradipta@gmail.com       | quas51          |
# |     18     | drg. Uli Hassanah, M.Pd         | drguli@gmail.com            | commodi60       |
# |     19     | Ibun Mayasari                   | ibunmayasari@gmail.com      | fugiat5         |
# |     93     | Ratna Rahimah                   | ratnarahimah@gmail.com      | provident77     |
# |     94     | Janet Farida                    | janetfarida@gmail.com       | magnam87        |
# |     95     | Ir. Jais Hutasoit               | irjais@gmail.com            | qui94           |
# |     96     | Carub Narpati                   | carubnarpati@gmail.com      | inventore44     |
# |     97     | Ghaliyati Nababan, M.Kom.       | ghaliyatinababan,@gmail.com | dignissimos23   |
# |     98     | Bahuraksa Halimah               | bahuraksahalimah@gmail.com  | mollitia36      |
# |     99     | Lala Melani, S.Pt               | lalamelani,@gmail.com       | consectetur71   |
# |    100     | Drs. Rafi Iswahyudi             | drsrafi@gmail.com           | deserunt74      |
# +------------+---------------------------------+-----------------------------+-----------------+

# %%
save_to_csv(data = users,
            nama_file = 'users')

# %%
#membuat tabel status_loan

def status_loan(is_print):
    status_loan = ['active', 'returned']
    n_cust = len(status_loan)
    tabel = {}
    tabel["status_loan_id"] = [i + 1 for i in range(n_cust)]
    tabel["status"] = status_loan
    if is_print:
        show_data(tabel)
    return tabel

# %%
status_loan= status_loan(True)
# Out:
# +------------------+----------+
# |  status_loan_id  | status   |
# |------------------+----------|
# |        1         | active   |
# |        2         | returned |
# +------------------+----------+

# %%
#menyimpan fie ke dalam csv
save_to_csv(data = status_loan,
            nama_file = 'status_loan')

# %%
# mendeskripsikan start dan end date yang diinginkan 
from datetime import datetime, timedelta

start_date = datetime.strptime("2025-01-01", "%Y-%m-%d").date()
end_date = datetime.strptime("2025-12-31", "%Y-%m-%d").date()

# %%
import random

# %%
# membuat tabel loan 
def loan(n_cust, is_print):
    tabel = {}
    tabel["loan_id"] = [i + 1 for i in range(n_cust)]
    tabel["users_id"] = [random.choice(users["users_id"]) for i in range(n_cust)]
    tabel["library_id"] = [random.choice(library["library_id"]) for i in range(n_cust)]
    tabel["book_id"] = [random.choice(book["book_id"]) for i in range(n_cust)]

    loan_dates = [fake.date_between(start_date=start_date, end_date=end_date) for _ in range(n_cust)]
    tabel["loan_date"] = loan_dates

    due_dates = [loan_date + timedelta(days=14) for loan_date in loan_dates]
    tabel["due_date"] = due_dates

    return_dates = []
    for loan_date in loan_dates:
        if random.random() < 0.7:  # 70% kemungkinan punya return_date
            return_dates.append(fake.date_between(start_date=loan_date + timedelta(days=1),
                                                  end_date=loan_date + timedelta(days= 14)))
        else:
            return_dates.append(None)  # sisanya None
    tabel["return_date"] = return_dates

    status_loan_id = []
    today = datetime.today().date()
    for return_date, due_date in zip(return_dates, due_dates):
        if return_date is not None:
            status_loan_id.append(2)  # returned
        else:
            status_loan_id.append(1)  # active
        
    tabel["status_loan_id"] = status_loan_id

    if is_print:
        show_data(tabel)
    return tabel

# %%
loan = loan (100, True)
# Out:
# +-----------+------------+--------------+-----------+-------------+------------+---------------+------------------+
# |  loan_id  |  users_id  |  library_id  | book_id   | loan_date   | due_date   | return_date   |  status_loan_id  |
# |-----------+------------+--------------+-----------+-------------+------------+---------------+------------------|
# |     1     |     35     |      78      | B - 043   | 2025-11-14  | 2025-11-28 | 2025-11-19    |        2         |
# |     2     |     13     |      8       | B - 045   | 2025-07-19  | 2025-08-02 | 2025-07-28    |        2         |
# |     3     |     84     |      31      | B - 065   | 2025-08-12  | 2025-08-26 |               |        1         |
# |     4     |     30     |      48      | B - 009   | 2025-11-10  | 2025-11-24 | 2025-11-19    |        2         |
# |     5     |     75     |      75      | B - 042   | 2025-10-15  | 2025-10-29 | 2025-10-25    |        2         |
# |     6     |     62     |      16      | B - 008   | 2025-06-12  | 2025-06-26 | 2025-06-19    |        2         |
# |     7     |     8      |      18      | B - 006   | 2025-07-18  | 2025-08-01 | 2025-07-30    |        2         |
# |     8     |     70     |      10      | B - 010   | 2025-05-23  | 2025-06-06 |               |        1         |
# |     9     |     77     |      47      | B - 078   | 2025-09-09  | 2025-09-23 | 2025-09-16    |        2         |
# |    10     |     48     |      52      | B - 088   | 2025-09-13  | 2025-09-27 | 2025-09-14    |        2         |
# |    11     |     64     |      82      | B - 053   | 2025-07-23  | 2025-08-06 |               |        1         |
# |    12     |     3      |      29      | B - 036   | 2025-08-06  | 2025-08-20 |               |        1         |
# |    13     |     36     |      44      | B - 004   | 2025-03-02  | 2025-03-16 | 2025-03-10    |        2         |
# |    14     |     13     |      15      | B - 088   | 2025-12-27  | 2026-01-10 | 2026-01-03    |        2         |
# |    15     |     27     |      42      | B - 042   | 2025-01-02  | 2025-01-16 |               |        1         |
# |    16     |     99     |      53      | B - 062   | 2025-12-15  | 2025-12-29 | 2025-12-23    |        2         |
# |    17     |     14     |      44      | B - 011   | 2025-01-22  | 2025-02-05 | 2025-01-27    |        2         |
# |    18     |     85     |      46      | B - 096   | 2025-06-14  | 2025-06-28 | 2025-06-27    |        2         |
# |    19     |     43     |      27      | B - 039   | 2025-04-18  | 2025-05-02 |               |        1         |
# |    20     |     5      |      32      | B - 085   | 2025-10-15  | 2025-10-29 | 2025-10-18    |        2         |
# |    21     |     98     |      97      | B - 079   | 2025-05-15  | 2025-05-29 | 2025-05-19    |        2         |
# |    22     |     71     |      16      | B - 052   | 2025-07-25  | 2025-08-08 | 2025-07-28    |        2         |
# |    23     |     40     |      87      | B - 081   | 2025-10-30  | 2025-11-13 |               |        1         |
# |    24     |     41     |     100      | B - 008   | 2025-05-28  | 2025-06-11 |               |        1         |
# |    25     |     21     |      89      | B - 099   | 2025-08-26  | 2025-09-09 |               |        1         |
# |    26     |     62     |      33      | B - 021   | 2025-01-29  | 2025-02-12 | 2025-02-03    |        2         |
# |    27     |     88     |      23      | B - 003   | 2025-03-18  | 2025-04-01 | 2025-03-26    |        2         |
# |    28     |     6      |      16      | B - 029   | 2025-05-27  | 2025-06-10 | 2025-06-02    |        2         |
# |    29     |     3      |      57      | B - 006   | 2025-10-12  | 2025-10-26 |               |        1         |
# |    30     |     55     |      74      | B - 040   | 2025-01-09  | 2025-01-23 |               |        1         |
# |    31     |     65     |      34      | B - 038   | 2025-11-11  | 2025-11-25 | 2025-11-16    |        2         |
# |    32     |     89     |      50      | B - 015   | 2025-11-26  | 2025-12-10 | 2025-12-09    |        2         |
# |    33     |     76     |      38      | B - 087   | 2025-10-26  | 2025-11-09 | 2025-10-31    |        2         |
# |    34     |     49     |      99      | B - 026   | 2025-08-31  | 2025-09-14 |               |        1         |
# |    35     |     7      |      45      | B - 074   | 2025-02-13  | 2025-02-27 | 2025-02-23    |        2         |
# |    36     |     65     |      28      | B - 049   | 2025-01-31  | 2025-02-14 |               |        1         |
# |    37     |     95     |      86      | B - 069   | 2025-03-12  | 2025-03-26 | 2025-03-22    |        2         |
# |    38     |     49     |      43      | B - 024   | 2025-11-06  | 2025-11-20 | 2025-11-10    |        2         |
# |    39     |     92     |      93      | B - 060   | 2025-03-22  | 2025-04-05 | 2025-03-30    |        2         |
# |    40     |     13     |      29      | B - 031   | 2025-05-04  | 2025-05-18 |               |        1         |
# |    41     |     48     |      35      | B - 023   | 2025-03-31  | 2025-04-14 | 2025-04-13    |        2         |
# |    42     |     53     |      90      | B - 087   | 2025-12-15  | 2025-12-29 |               |        1         |
# |    43     |     30     |      8       | B - 022   | 2025-12-19  | 2026-01-02 | 2025-12-31    |        2         |
# |    44     |     85     |      74      | B - 070   | 2025-05-14  | 2025-05-28 | 2025-05-17    |        2         |
# |    45     |     17     |      4       | B - 037   | 2025-10-02  | 2025-10-16 | 2025-10-12    |        2         |
# |    46     |    100     |      46      | B - 067   | 2025-09-08  | 2025-09-22 |               |        1         |
# |    47     |     95     |      20      | B - 084   | 2025-01-16  | 2025-01-30 |               |        1         |
# |    48     |     82     |      67      | B - 061   | 2025-11-01  | 2025-11-15 | 2025-11-05    |        2         |
# |    49     |     56     |      8       | B - 039   | 2025-04-29  | 2025-05-13 |               |        1         |
# |    50     |     93     |      2       | B - 089   | 2025-10-11  | 2025-10-25 | 2025-10-13    |        2         |
# |    51     |     42     |      87      | B - 092   | 2025-08-22  | 2025-09-05 | 2025-08-23    |        2         |
# |    52     |     14     |      95      | B - 033   | 2025-11-22  | 2025-12-06 |               |        1         |
# |    53     |     39     |      97      | B - 016   | 2025-06-14  | 2025-06-28 | 2025-06-26    |        2         |
# |    54     |     77     |      30      | B - 010   | 2025-12-26  | 2026-01-09 | 2025-12-31    |        2         |
# |    55     |     27     |      56      | B - 019   | 2025-06-10  | 2025-06-24 | 2025-06-21    |        2         |
# |    56     |     43     |      13      | B - 076   | 2025-09-13  | 2025-09-27 |               |        1         |
# |    57     |     84     |      27      | B - 024   | 2025-11-10  | 2025-11-24 | 2025-11-23    |        2         |
# |    58     |     41     |      3       | B - 025   | 2025-06-30  | 2025-07-14 |               |        1         |
# |    59     |     10     |      92      | B - 081   | 2025-12-12  | 2025-12-26 | 2025-12-23    |        2         |
# |    60     |     96     |      95      | B - 047   | 2025-01-02  | 2025-01-16 |               |        1         |
# |    61     |     2      |      94      | B - 046   | 2025-05-30  | 2025-06-13 | 2025-06-12    |        2         |
# |    62     |     25     |      55      | B - 009   | 2025-12-18  | 2026-01-01 |               |        1         |
# |    63     |     62     |      63      | B - 088   | 2025-10-09  | 2025-10-23 | 2025-10-20    |        2         |
# |    64     |     36     |      53      | B - 014   | 2025-02-24  | 2025-03-10 |               |        1         |
# |    65     |     31     |      70      | B - 039   | 2025-09-17  | 2025-10-01 |               |        1         |
# |    66     |     84     |      73      | B - 029   | 2025-11-10  | 2025-11-24 |               |        1         |
# |    67     |     98     |      65      | B - 091   | 2025-03-19  | 2025-04-02 | 2025-03-22    |        2         |
# |    68     |     70     |      14      | B - 019   | 2025-07-24  | 2025-08-07 | 2025-07-30    |        2         |
# |    69     |     64     |      83      | B - 093   | 2025-05-20  | 2025-06-03 | 2025-05-22    |        2         |
# |    70     |     65     |      81      | B - 049   | 2025-04-22  | 2025-05-06 |               |        1         |
# |    71     |     71     |      57      | B - 012   | 2025-07-07  | 2025-07-21 | 2025-07-15    |        2         |
# |    72     |     76     |      49      | B - 009   | 2025-12-19  | 2026-01-02 |               |        1         |
# |    73     |     47     |      55      | B - 076   | 2025-02-13  | 2025-02-27 | 2025-02-20    |        2         |
# |    74     |     49     |      74      | B - 037   | 2025-05-13  | 2025-05-27 | 2025-05-21    |        2         |
# |    75     |     62     |      82      | B - 093   | 2025-08-24  | 2025-09-07 | 2025-09-03    |        2         |
# |    76     |     50     |      33      | B - 025   | 2025-02-19  | 2025-03-05 | 2025-02-28    |        2         |
# |    77     |     11     |      10      | B - 026   | 2025-01-13  | 2025-01-27 | 2025-01-24    |        2         |
# |    78     |     68     |      82      | B - 027   | 2025-03-31  | 2025-04-14 | 2025-04-08    |        2         |
# |    79     |     90     |      70      | B - 087   | 2025-10-17  | 2025-10-31 | 2025-10-30    |        2         |
# |    80     |     56     |      13      | B - 040   | 2025-01-15  | 2025-01-29 |               |        1         |
# |    81     |     16     |      23      | B - 057   | 2025-09-16  | 2025-09-30 | 2025-09-24    |        2         |
# |    82     |     28     |      86      | B - 069   | 2025-06-22  | 2025-07-06 |               |        1         |
# |    83     |     14     |      78      | B - 099   | 2025-02-04  | 2025-02-18 | 2025-02-17    |        2         |
# |    84     |     89     |      44      | B - 046   | 2025-09-13  | 2025-09-27 | 2025-09-18    |        2         |
# |    85     |     55     |      86      | B - 085   | 2025-01-12  | 2025-01-26 | 2025-01-14    |        2         |
# |    86     |     55     |      96      | B - 086   | 2025-10-25  | 2025-11-08 | 2025-11-01    |        2         |
# |    87     |     24     |      82      | B - 050   | 2025-02-20  | 2025-03-06 |               |        1         |
# |    88     |     25     |      24      | B - 031   | 2025-01-30  | 2025-02-13 | 2025-02-02    |        2         |
# |    89     |     82     |      37      | B - 016   | 2025-09-01  | 2025-09-15 | 2025-09-05    |        2         |
# |    90     |     10     |      5       | B - 010   | 2025-02-28  | 2025-03-14 | 2025-03-04    |        2         |
# |    91     |     87     |      46      | B - 016   | 2025-06-19  | 2025-07-03 | 2025-06-20    |        2         |
# |    92     |     20     |      45      | B - 002   | 2025-05-05  | 2025-05-19 |               |        1         |
# |    93     |     77     |      10      | B - 092   | 2025-10-01  | 2025-10-15 | 2025-10-14    |        2         |
# |    94     |     25     |      78      | B - 085   | 2025-12-13  | 2025-12-27 | 2025-12-21    |        2         |
# |    95     |     24     |      87      | B - 087   | 2025-02-16  | 2025-03-02 | 2025-02-24    |        2         |
# |    96     |     72     |      87      | B - 061   | 2025-02-25  | 2025-03-11 |               |        1         |
# |    97     |    100     |      50      | B - 076   | 2025-06-01  | 2025-06-15 | 2025-06-04    |        2         |
# |    98     |     78     |      98      | B - 075   | 2025-05-23  | 2025-06-06 |               |        1         |
# |    99     |     48     |      98      | B - 094   | 2025-09-16  | 2025-09-30 | 2025-09-17    |        2         |
# |    100    |     72     |      90      | B - 021   | 2025-04-18  | 2025-05-02 |               |        1         |
# +-----------+------------+--------------+-----------+-------------+------------+---------------+------------------+

# %%
save_to_csv(data = loan,
            nama_file = 'loan')

# %%
def status_hold(is_print):
    tabel= {
        "status_hold_id" :[],
        "status" :[],
    }
    status = ['waiting', 'expired', 'fulfilled']
    n_cust = len(status)
    for i in range (n_cust):
        tabel["status_hold_id"].append(i+1)
    tabel["status"] = status
    if is_print: 
        show_data(tabel)
    return tabel

# %%
status_hold = status_hold(True)
# Out:
# +------------------+-----------+
# |  status_hold_id  | status    |
# |------------------+-----------|
# |        1         | waiting   |
# |        2         | expired   |
# |        3         | fulfilled |
# +------------------+-----------+

# %%
save_to_csv(data = status_hold,
            nama_file = 'status_hold')

# %%
from datetime import datetime, timedelta

start_date = datetime.strptime("2025-01-01", "%Y-%m-%d").date()
end_date = datetime.strptime("2025-12-31", "%Y-%m-%d").date()

# %%
def hold_1(n_cust, is_print):
    tabel = {
        "hold_id":[i+1 for i in range(n_cust)],
        "users_id" : [ random.choice(users["users_id"]) for i in range(n_cust)],
        "library_id": [random.choice(library["library_id"]) for i in range(n_cust)],
        "book_id" : [random.choice(book["book_id"]) for i in range(n_cust)], 
        "hold_date" : [],
        "available_date" :[],
        "expired_date": [],
        "pickup_date" : [],
        "status_hold_id" : []
    }
    today = datetime.today().date()
    
    for i in range(n_cust):
        hold_date = fake.date_between(start_date = start_date, end_date= end_date)
        available_date = fake.date_between(start_date = hold_date+timedelta(days=1), end_date= hold_date + timedelta(days=56))
        expired_date = available_date + timedelta(days = 7)
        #pickup date
        if random.random() < 0.7:  # 70% kemungkinan 
            pickup_date = fake.date_between(start_date=available_date + timedelta(days = 1),
                                                      end_date= available_date + timedelta(days=6))
        else:
            pickup_date = None  # sisanya None
        #mengecek status hold
        if pickup_date is not None:
            status_hold_id = 3# fullfield
        else:
            if  today > expired_date:
                status_hold_id= 2  # expierd
            else:
                status_hold_id = 1 # waiting
        tabel["pickup_date"].append(pickup_date)
        tabel["hold_date"].append(hold_date)
        tabel["expired_date"].append(expired_date)
        tabel["available_date"].append(available_date)
        tabel["status_hold_id"]. append(status_hold_id)
    if is_print: 
        show_data(tabel)
    return tabel

# %%
hold_1= hold_1(100, True)
# Out:
# +-----------+------------+--------------+-----------+-------------+------------------+----------------+---------------+------------------+
# |  hold_id  |  users_id  |  library_id  | book_id   | hold_date   | available_date   | expired_date   | pickup_date   |  status_hold_id  |
# |-----------+------------+--------------+-----------+-------------+------------------+----------------+---------------+------------------|
# |     1     |     11     |      64      | B - 048   | 2025-11-26  | 2026-01-07       | 2026-01-14     | 2026-01-10    |        3         |
# |     2     |     23     |      11      | B - 007   | 2025-03-23  | 2025-04-25       | 2025-05-02     | 2025-04-28    |        3         |
# |     3     |     72     |      10      | B - 072   | 2025-01-11  | 2025-02-01       | 2025-02-08     | 2025-02-06    |        3         |
# |     4     |     83     |      99      | B - 077   | 2025-05-10  | 2025-06-17       | 2025-06-24     | 2025-06-18    |        3         |
# |     5     |     61     |      60      | B - 042   | 2025-02-03  | 2025-02-09       | 2025-02-16     |               |        2         |
# |     6     |     15     |      98      | B - 077   | 2025-02-01  | 2025-02-25       | 2025-03-04     | 2025-02-28    |        3         |
# |     7     |     18     |      13      | B - 002   | 2025-01-31  | 2025-03-07       | 2025-03-14     | 2025-03-12    |        3         |
# |     8     |     30     |      52      | B - 015   | 2025-02-26  | 2025-03-09       | 2025-03-16     |               |        2         |
# |     9     |     66     |      49      | B - 028   | 2025-11-18  | 2026-01-05       | 2026-01-12     |               |        1         |
# |    10     |     47     |      41      | B - 017   | 2025-11-01  | 2025-11-17       | 2025-11-24     | 2025-11-21    |        3         |
# |    11     |     37     |      47      | B - 065   | 2025-11-02  | 2025-12-22       | 2025-12-29     | 2025-12-27    |        3         |
# |    12     |     16     |      83      | B - 066   | 2025-07-10  | 2025-08-10       | 2025-08-17     | 2025-08-15    |        3         |
# |    13     |     43     |      34      | B - 003   | 2025-11-23  | 2025-12-03       | 2025-12-10     |               |        1         |
# |    14     |     84     |      36      | B - 038   | 2025-04-07  | 2025-05-10       | 2025-05-17     | 2025-05-14    |        3         |
# |    15     |     17     |      50      | B - 034   | 2025-12-03  | 2025-12-19       | 2025-12-26     |               |        1         |
# |    16     |     59     |      64      | B - 032   | 2025-07-31  | 2025-08-16       | 2025-08-23     | 2025-08-17    |        3         |
# |    17     |     54     |      69      | B - 057   | 2025-06-28  | 2025-07-24       | 2025-07-31     | 2025-07-29    |        3         |
# |    18     |     53     |      9       | B - 055   | 2025-03-08  | 2025-03-19       | 2025-03-26     | 2025-03-21    |        3         |
# |    19     |     89     |      89      | B - 044   | 2025-08-16  | 2025-09-16       | 2025-09-23     | 2025-09-18    |        3         |
# |    20     |     31     |      35      | B - 034   | 2025-11-21  | 2025-12-03       | 2025-12-10     |               |        1         |
# |    21     |     37     |      9       | B - 081   | 2025-08-09  | 2025-08-22       | 2025-08-29     | 2025-08-24    |        3         |
# |    22     |     39     |      50      | B - 100   | 2025-09-16  | 2025-11-06       | 2025-11-13     |               |        1         |
# |    23     |     80     |      67      | B - 034   | 2025-09-22  | 2025-10-10       | 2025-10-17     | 2025-10-15    |        3         |
# |    24     |     69     |      97      | B - 020   | 2025-06-27  | 2025-06-28       | 2025-07-05     |               |        1         |
# |    25     |     19     |      90      | B - 036   | 2025-09-28  | 2025-11-21       | 2025-11-28     | 2025-11-25    |        3         |
# |    26     |     79     |      72      | B - 024   | 2025-02-20  | 2025-03-02       | 2025-03-09     | 2025-03-04    |        3         |
# |    27     |     19     |      94      | B - 062   | 2025-02-27  | 2025-04-18       | 2025-04-25     | 2025-04-20    |        3         |
# |    28     |     30     |      92      | B - 003   | 2025-08-16  | 2025-08-20       | 2025-08-27     | 2025-08-21    |        3         |
# |    29     |     57     |      47      | B - 052   | 2025-02-16  | 2025-04-10       | 2025-04-17     | 2025-04-14    |        3         |
# |    30     |     67     |      63      | B - 071   | 2025-03-10  | 2025-04-22       | 2025-04-29     | 2025-04-25    |        3         |
# |    31     |     11     |      87      | B - 011   | 2025-10-10  | 2025-11-10       | 2025-11-17     | 2025-11-13    |        3         |
# |    32     |     67     |      8       | B - 092   | 2025-02-20  | 2025-04-13       | 2025-04-20     | 2025-04-15    |        3         |
# |    33     |     81     |      93      | B - 023   | 2025-05-01  | 2025-05-11       | 2025-05-18     | 2025-05-14    |        3         |
# |    34     |     12     |      2       | B - 050   | 2025-01-09  | 2025-02-20       | 2025-02-27     | 2025-02-24    |        3         |
# |    35     |     16     |      44      | B - 047   | 2025-08-11  | 2025-09-12       | 2025-09-19     |               |        1         |
# |    36     |     81     |      51      | B - 006   | 2025-02-10  | 2025-03-18       | 2025-03-25     |               |        2         |
# |    37     |     64     |      89      | B - 065   | 2025-06-03  | 2025-06-19       | 2025-06-26     | 2025-06-24    |        3         |
# |    38     |     58     |      62      | B - 092   | 2025-11-01  | 2025-12-08       | 2025-12-15     |               |        1         |
# |    39     |     44     |      60      | B - 043   | 2025-11-02  | 2025-11-04       | 2025-11-11     | 2025-11-07    |        3         |
# |    40     |     37     |      87      | B - 073   | 2025-12-13  | 2025-12-31       | 2026-01-07     | 2026-01-04    |        3         |
# |    41     |     14     |      68      | B - 044   | 2025-08-29  | 2025-10-08       | 2025-10-15     | 2025-10-09    |        3         |
# |    42     |     44     |      38      | B - 088   | 2025-03-05  | 2025-04-29       | 2025-05-06     | 2025-05-03    |        3         |
# |    43     |     80     |      13      | B - 047   | 2025-10-18  | 2025-10-20       | 2025-10-27     |               |        1         |
# |    44     |     6      |      42      | B - 051   | 2025-02-13  | 2025-03-31       | 2025-04-07     | 2025-04-02    |        3         |
# |    45     |     66     |      74      | B - 085   | 2025-11-23  | 2025-12-03       | 2025-12-10     |               |        1         |
# |    46     |     53     |      8       | B - 038   | 2025-01-20  | 2025-02-05       | 2025-02-12     | 2025-02-07    |        3         |
# |    47     |     53     |      34      | B - 098   | 2025-12-27  | 2026-02-06       | 2026-02-13     | 2026-02-07    |        3         |
# |    48     |     62     |      73      | B - 088   | 2025-10-19  | 2025-11-10       | 2025-11-17     | 2025-11-15    |        3         |
# |    49     |     71     |      7       | B - 049   | 2025-03-24  | 2025-05-10       | 2025-05-17     | 2025-05-12    |        3         |
# |    50     |     24     |      86      | B - 086   | 2025-12-27  | 2026-01-16       | 2026-01-23     | 2026-01-19    |        3         |
# |    51     |     3      |      17      | B - 046   | 2025-11-20  | 2026-01-11       | 2026-01-18     |               |        1         |
# |    52     |     17     |      43      | B - 092   | 2025-01-15  | 2025-02-26       | 2025-03-05     | 2025-02-27    |        3         |
# |    53     |     82     |      97      | B - 007   | 2025-01-18  | 2025-01-28       | 2025-02-04     | 2025-01-29    |        3         |
# |    54     |     97     |      41      | B - 080   | 2025-02-02  | 2025-02-27       | 2025-03-06     |               |        2         |
# |    55     |     65     |      68      | B - 007   | 2025-11-09  | 2025-12-24       | 2025-12-31     | 2025-12-26    |        3         |
# |    56     |     13     |      60      | B - 066   | 2025-06-08  | 2025-06-29       | 2025-07-06     | 2025-07-01    |        3         |
# |    57     |     19     |      67      | B - 047   | 2025-11-26  | 2025-12-15       | 2025-12-22     | 2025-12-16    |        3         |
# |    58     |     77     |      95      | B - 044   | 2025-06-20  | 2025-08-08       | 2025-08-15     | 2025-08-11    |        3         |
# |    59     |     60     |      24      | B - 097   | 2025-10-31  | 2025-11-20       | 2025-11-27     | 2025-11-25    |        3         |
# |    60     |     17     |      26      | B - 009   | 2025-12-29  | 2026-01-22       | 2026-01-29     | 2026-01-26    |        3         |
# |    61     |     49     |      4       | B - 034   | 2025-06-23  | 2025-07-23       | 2025-07-30     |               |        1         |
# |    62     |     74     |      75      | B - 070   | 2025-07-02  | 2025-08-18       | 2025-08-25     |               |        1         |
# |    63     |     28     |      85      | B - 078   | 2025-12-08  | 2025-12-19       | 2025-12-26     | 2025-12-24    |        3         |
# |    64     |     36     |      73      | B - 090   | 2025-08-05  | 2025-08-19       | 2025-08-26     | 2025-08-22    |        3         |
# |    65     |     27     |      35      | B - 004   | 2025-08-02  | 2025-09-24       | 2025-10-01     |               |        1         |
# |    66     |     49     |      30      | B - 065   | 2025-09-09  | 2025-09-15       | 2025-09-22     | 2025-09-17    |        3         |
# |    67     |     16     |      2       | B - 078   | 2025-07-20  | 2025-08-26       | 2025-09-02     | 2025-08-27    |        3         |
# |    68     |     25     |      46      | B - 090   | 2025-07-18  | 2025-08-22       | 2025-08-29     |               |        1         |
# |    69     |     81     |      28      | B - 056   | 2025-02-02  | 2025-02-10       | 2025-02-17     | 2025-02-13    |        3         |
# |    70     |     48     |      1       | B - 086   | 2025-10-12  | 2025-11-08       | 2025-11-15     | 2025-11-11    |        3         |
# |    71     |     69     |      3       | B - 087   | 2025-10-29  | 2025-11-28       | 2025-12-05     | 2025-12-01    |        3         |
# |    72     |     21     |      46      | B - 003   | 2025-05-05  | 2025-05-14       | 2025-05-21     | 2025-05-17    |        3         |
# |    73     |     25     |      34      | B - 070   | 2025-01-18  | 2025-01-25       | 2025-02-01     | 2025-01-29    |        3         |
# |    74     |     27     |      62      | B - 003   | 2025-07-12  | 2025-09-03       | 2025-09-10     | 2025-09-04    |        3         |
# |    75     |     73     |      60      | B - 072   | 2025-02-25  | 2025-03-24       | 2025-03-31     | 2025-03-27    |        3         |
# |    76     |     95     |      85      | B - 054   | 2025-05-21  | 2025-07-13       | 2025-07-20     |               |        1         |
# |    77     |     36     |      55      | B - 057   | 2025-11-15  | 2025-11-28       | 2025-12-05     | 2025-12-01    |        3         |
# |    78     |     83     |      21      | B - 003   | 2025-11-23  | 2025-12-16       | 2025-12-23     |               |        1         |
# |    79     |     30     |      32      | B - 094   | 2025-02-03  | 2025-03-15       | 2025-03-22     | 2025-03-18    |        3         |
# |    80     |     2      |      8       | B - 057   | 2025-06-17  | 2025-07-07       | 2025-07-14     |               |        1         |
# |    81     |     52     |      49      | B - 044   | 2025-10-02  | 2025-10-12       | 2025-10-19     | 2025-10-14    |        3         |
# |    82     |     86     |      65      | B - 055   | 2025-07-24  | 2025-07-25       | 2025-08-01     |               |        1         |
# |    83     |     89     |      47      | B - 006   | 2025-07-17  | 2025-07-22       | 2025-07-29     | 2025-07-26    |        3         |
# |    84     |     65     |      99      | B - 053   | 2025-10-12  | 2025-11-13       | 2025-11-20     | 2025-11-15    |        3         |
# |    85     |     19     |      52      | B - 084   | 2025-01-05  | 2025-01-26       | 2025-02-02     | 2025-01-27    |        3         |
# |    86     |     84     |      25      | B - 057   | 2025-05-17  | 2025-06-20       | 2025-06-27     | 2025-06-21    |        3         |
# |    87     |     5      |      81      | B - 068   | 2025-03-04  | 2025-03-15       | 2025-03-22     | 2025-03-20    |        3         |
# |    88     |     60     |      8       | B - 088   | 2025-03-24  | 2025-04-19       | 2025-04-26     | 2025-04-23    |        3         |
# |    89     |     24     |      61      | B - 027   | 2025-12-13  | 2026-02-02       | 2026-02-09     |               |        1         |
# |    90     |     64     |      75      | B - 034   | 2025-03-06  | 2025-04-22       | 2025-04-29     | 2025-04-26    |        3         |
# |    91     |     9      |      67      | B - 016   | 2025-09-08  | 2025-09-18       | 2025-09-25     | 2025-09-23    |        3         |
# |    92     |     30     |      72      | B - 004   | 2025-11-26  | 2025-12-10       | 2025-12-17     |               |        1         |
# |    93     |     83     |      91      | B - 087   | 2025-04-24  | 2025-05-21       | 2025-05-28     | 2025-05-25    |        3         |
# |    94     |     59     |      82      | B - 052   | 2025-09-25  | 2025-11-05       | 2025-11-12     |               |        1         |
# |    95     |     73     |      18      | B - 061   | 2025-11-29  | 2025-12-08       | 2025-12-15     | 2025-12-11    |        3         |
# |    96     |     77     |      82      | B - 048   | 2025-09-16  | 2025-10-18       | 2025-10-25     |               |        1         |
# |    97     |     96     |      77      | B - 085   | 2025-02-07  | 2025-03-26       | 2025-04-02     | 2025-03-27    |        3         |
# |    98     |     88     |      4       | B - 062   | 2025-09-30  | 2025-11-21       | 2025-11-28     | 2025-11-22    |        3         |
# |    99     |     81     |      86      | B - 085   | 2025-11-18  | 2025-11-25       | 2025-12-02     |               |        1         |
# |    100    |     73     |      10      | B - 089   | 2025-11-13  | 2025-12-05       | 2025-12-12     | 2025-12-08    |        3         |
# +-----------+------------+--------------+-----------+-------------+------------------+----------------+---------------+------------------+

# %%
save_to_csv(data = hold_1,
            nama_file = 'hold')
